# %%
data <- read.csv(("C:\\Users\\rehan\\AppData\\Local\\Packages\\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\\LocalState\\sessions\\81212264D0BB4AECC69930381B2B99B11621FFE3\\transfers\\2026-12\\Missing_values.csv"))
print("Original Data:")
print(data)
# Out:
# [1] "Original Data:"
#    ID      Name Age Salary
# 1   1      John  25  50000
# 2   2      Anna  30  60000
# 3   3      Mike  NA  45000
# 4   4      Sara  28     NA
# 5   5       Tom  35  70000
# 6   6      Lisa  NA  55000
# 7   7      Eric  40  65000
# 8   8       Amy  29     NA
# 9   9       Bob  32  48000
# 10 10      Ella  NA  52000
# 11 11     David  27  51000
# 12 12    Olivia  31  62000
# 13 13      Liam  NA  47000
# 14 14    Sophia  26     NA
# 15 15      Noah  34  68000
# 16 16      Emma  NA  54000
# 17 17     James  38  72000
# 18 18       Ava  29     NA
# 19 19   William  33  56000
# 20 20       Mia  NA  59000
# 21 21  Benjamin  28  53000
# 22 22 Charlotte  30  61000
# 23 23     Lucas  NA  46000
# 24 24    Amelia  27     NA
# 25 25     Henry  36  75000
# 26 26    Harper  NA  52000
# 27 27 Alexander  41  67000
# 28 28    Evelyn  28     NA
# 29 29   Michael  35  64000
# 30 30   Abigail  NA  58000
# 31 31    Daniel  26  50000
# 32 32     Emily  31  63000
# 33 33   Matthew  NA  48000
# 34 34 Elizabeth  29     NA
# 35 35   Jackson  37  71000
# 36 36     Sofia  NA  56000
# 37 37 Sebastian  40  69000
# 38 38     Avery  28     NA
# 39 39     Aiden  33  54000
# 40 40      Ella  NA  60000
# 41 41     Logan  27  52000
# 42 42  Scarlett  30  65000
# 43 43    Carter  NA  47000
# 44 44  Victoria  28     NA
# 45 45    Jayden  36  73000
# 46 46     Grace  NA  55000
# 47 47      Luke  39  68000
# 48 48     Chloe  29     NA
# 49 49   Gabriel  34  62000
# 50 50       Zoe  NA  57000

# %%
print("Number of na values in each column: ")
print(colSums(is.na(data)))
# Out:
# [1] "Number of na values in each column: "
#     ID   Name    Age Salary
#      0      0     15     10

# %%
numeric_cols <- sapply(data, is.numeric)
print("numeric Columns:")
print(numeric_cols)
# Out:
# [1] "numeric Columns:"
#     ID   Name    Age Salary
#   TRUE  FALSE   TRUE   TRUE

# %%
print("Mean Values (Ignoring NA): ")
mean_values <- colMeans(data[, numeric_cols], na.rm = TRUE)
print(mean_values)
# Out:
# [1] "Mean Values (Ignoring NA): "
#          ID         Age      Salary
#    25.50000    31.68571 58500.00000

# %%
par(mar = c(5,4,4,2))
hist(data$Salary,
	main = "Salary Distribution",
	xlab = "Salary",
	col = "lightgreen")
# Out:
# Plot with title "Salary Distribution"

# %%
for (i in colnames(data)) {
	if (is.numeric(data[[i]])) {
		mean_values <- mean(data[[i]], na.rm = TRUE)
		data[[i]][is.na(data[[i]])] <- mean_values
	}
}

# %%
print("Data After Imputation:")
print(data)
# Out:
# [1] "Data After Imputation:"
#    ID      Name      Age Salary
# 1   1      John 25.00000  50000
# 2   2      Anna 30.00000  60000
# 3   3      Mike 31.68571  45000
# 4   4      Sara 28.00000  58500
# 5   5       Tom 35.00000  70000
# 6   6      Lisa 31.68571  55000
# 7   7      Eric 40.00000  65000
# 8   8       Amy 29.00000  58500
# 9   9       Bob 32.00000  48000
# 10 10      Ella 31.68571  52000
# 11 11     David 27.00000  51000
# 12 12    Olivia 31.00000  62000
# 13 13      Liam 31.68571  47000
# 14 14    Sophia 26.00000  58500
# 15 15      Noah 34.00000  68000
# 16 16      Emma 31.68571  54000
# 17 17     James 38.00000  72000
# 18 18       Ava 29.00000  58500
# 19 19   William 33.00000  56000
# 20 20       Mia 31.68571  59000
# 21 21  Benjamin 28.00000  53000
# 22 22 Charlotte 30.00000  61000
# 23 23     Lucas 31.68571  46000
# 24 24    Amelia 27.00000  58500
# 25 25     Henry 36.00000  75000
# 26 26    Harper 31.68571  52000
# 27 27 Alexander 41.00000  67000
# 28 28    Evelyn 28.00000  58500
# 29 29   Michael 35.00000  64000
# 30 30   Abigail 31.68571  58000
# 31 31    Daniel 26.00000  50000
# 32 32     Emily 31.00000  63000
# 33 33   Matthew 31.68571  48000
# 34 34 Elizabeth 29.00000  58500
# 35 35   Jackson 37.00000  71000
# 36 36     Sofia 31.68571  56000
# 37 37 Sebastian 40.00000  69000
# 38 38     Avery 28.00000  58500
# 39 39     Aiden 33.00000  54000
# 40 40      Ella 31.68571  60000
# 41 41     Logan 27.00000  52000
# 42 42  Scarlett 30.00000  65000
# 43 43    Carter 31.68571  47000
# 44 44  Victoria 28.00000  58500
# 45 45    Jayden 36.00000  73000
# 46 46     Grace 31.68571  55000
# 47 47      Luke 39.00000  68000
# 48 48     Chloe 29.00000  58500
# 49 49   Gabriel 34.00000  62000
# 50 50       Zoe 31.68571  57000

# %%
print("Mean after imputation: ")
new_mean <- colMeans(data[, numeric_cols])
print(new_mean)
# Out:
# [1] "Mean after imputation: "
#          ID         Age      Salary
#    25.50000    31.68571 58500.00000

# %%
hist(data$Salary,
	main = "Salary Distribution After Imputation",
	xlab = "Salary",
	col = "pink",)
# Out:
# Plot with title "Salary Distribution After Imputation"

# %%
boxplot(data$Salary,
	main = "Salary Distribution",
	col = "yellow")
# Out:
# Plot with title "Salary Distribution"

# %%
plot(data$Age, data$Salary,
	main = "Age vs Salary",
	xlab = "Age",
	ylab = "Salary",
	pch = 12,
	col = "red")
# Out:
# Plot with title "Age vs Salary"

# %%
print("Summary of the dataset:")
summary(data)
# Out:
# [1] "Summary of the dataset:"
#        ID               Name         Age            Salary
#  Min.   : 1.00   Ella     : 2   Min.   :25.00   Min.   :45000
#  1st Qu.:13.25   Abigail  : 1   1st Qu.:29.00   1st Qu.:53250
#  Median :25.50   Aiden    : 1   Median :31.69   Median :58500
#  Mean   :25.50   Alexander: 1   Mean   :31.69   Mean   :58500
#  3rd Qu.:37.75   Amelia   : 1   3rd Qu.:33.00   3rd Qu.:62750
#  Max.   :50.00   Amy      : 1   Max.   :41.00   Max.   :75000
#                  (Other)  :43
