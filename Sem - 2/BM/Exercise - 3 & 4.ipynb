# %% [markdown]
# Exercise 3

# %%
from sympy import *
x = Symbol('x')
y = Symbol('y')
z = Symbol('z')

# %%
diff(sin(4*x)*cos(3*x), x)
# Out:
# -3*sin(3*x)*sin(4*x) + 4*cos(3*x)*cos(4*x)

# %%
u = x**3+y**3+z**3-3*x*y*z
s = simplify(x*diff(u,x)+y*diff(u,y)+z*diff(u,z))
s
# Out:
# 3*x**3 - 9*x*y*z + 3*y**3 + 3*z**3

# %% [markdown]
# <h2 style = "text-align:center;">
# Exercise 4
# </h2>

# %%
from sympy import *

# %%
f2=(1-2*x*y+y**2)**Rational(-1,2)
ans=x*diff(f2,x)-y*diff(f2,y)
S=simplify(ans)
S
# Out:
# y**2/(-2*x*y + y**2 + 1)**(3/2)

# %%
f3=x**2*y+y**2*z+z**2*x
ans=diff(f3,x)+diff(f3,y)+diff(f3,z)
S=simplify(ans)
S
# Out:
# x**2 + 2*x*y + 2*x*z + y**2 + 2*y*z + z**2

# %%
u=x*y**2+y**2*z+x**2*y
ans=diff(u,x)+diff(u,y)+diff(u,z)
S=simplify(ans)
S
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 u=x*y**2+y**2*z+x**2*y
#       2 ans=diff(u,x)+diff(u,y)+diff(u,z)
#       3 S=simplify(ans)
#
# NameError: name 'x' is not defined

# %%
u= x**y +y**x
ans=diff(u,x)+diff(u,y)
S=simplify(ans)
S
# Out:
# x*y**x/y + x**y*log(x) + y**x*log(y) + x**y*y/x

# %%
u = ln(x**4+y**4*x-y)
ans=diff(u,x)+diff(u,y)+diff(u,z)
S=simplify(ans)
S
# Out:
# (4*x**3 + 4*x*y**3 + y**4 - 1)/(x**4 + x*y**4 - y)

# %%
u = x**2*y + y
expr = x**2*diff(u,x,2) + y**2*diff(u,y,2) + 2*x*y*diff(u,x,y)
S = simplify(expr)
S
# Out:
# 6*x**2*y

# %%
u = sqrt(x**2 + y**2 + z**2)
expr = diff(u,x)**2 + diff(u,y)**2 + diff(u,z)**2
S = simplify(expr)
S
# Out:
# 1

# %%
u = x**3 - 2*x**2*y + 3*x*y**2 + y**3
expr = x**2*diff(u,x) + y**2*diff(u,y)
S = simplify(expr)
S
# Out:
# 3*x**4 - 4*x**3*y + x**2*y**2 + 6*x*y**3 + 3*y**4

# %%
u = 3*x**2*y*z + 4*x*y**2*z + 5*y**4
expr = diff(u,x) + diff(u,y) + diff(u,z)
S = simplify(expr)
S
# Out:
# 3*x**2*y + 3*x**2*z + 4*x*y**2 + 14*x*y*z + 20*y**3 + 4*y**2*z

# %%
u = exp(x)*(x*cos(y) - y*sin(y))
expr = diff(u,x,2) + diff(u,y,2)
S = simplify(expr)
S
# Out:
# 0

# %%
u = y/z + z/x + x/y
expr = x*diff(u,x) + y*diff(u,y) + z*diff(u,z)
S = simplify(expr)
S
# Out:
# 0

# %%
u = (x*y)/(x+y)
expr = x**2*diff(u,x,2) + y**2*diff(u,y,2) + 2*x*y*diff(u,x,y)
S = simplify(expr)
S
# Out:
# 0
