# %%
import pandas as pd

# %%
new_employees = pd.DataFrame({
    "name":   ["Aisha", "Rohan"],
    "dept":   ["Tech", "Finance"],
    "city":   ["Delhi", "Mumbai"],
    "salary": [83000, 64000],
    "rating": [4.4, 3.9]
})

# %%
df = pd.DataFrame({
    "name":     ["Ravi", "Sneha", "Arjun", "Priya", "Karan", "Meera", "Dev", "Tara"],
    "dept":     ["Tech", "Tech", "Finance", "Finance", "HR", "Tech", "HR", "Finance"],
    "city":     ["Mumbai", "Delhi", "Mumbai", "Chennai", "Delhi", "Mumbai", "Chennai", "Delhi"],
    "salary":   [88000, 76000, 61000, 57000, 44000, 91000, 47000, 69000],
    "rating":   [4.7, 4.1, 3.8, 3.6, 4.2, 4.9, 3.5, 4.0]
})

# %%
len(pd.concat([df, new_employees], ignore_index=True))
# Out:
# 10

# %%
df = pd.DataFrame({
    "name":     ["Alice", "Bob", "Charlie", "Diana", "Eve", "Frank", "Grace", "Henry"],
    "dept":     ["Tech", "Tech", "Finance", "Finance", "HR", "HR", "Tech", "Finance"],
    "city":     ["Mumbai", "Delhi", "Mumbai", "Chennai", "Delhi", "Mumbai", "Chennai", "Delhi"],
    "salary":   [90000, 75000, 62000, 58000, 45000, 48000, 88000, 67000],
    "rating":   [4.8, 4.2, 3.9, 3.5, 4.0, 3.7, 4.6, 4.1],
    "joined":   [pd.Timestamp("2021-03-15"), pd.Timestamp("2020-07-01"), pd.Timestamp("2019-11-20"), pd.Timestamp("2018-06-10"),
                 pd.Timestamp("2022-01-10"), pd.Timestamp("2017-09-05"), pd.Timestamp("2021-08-22"), pd.Timestamp("2020-03-18")],
    "resigned": [False, False, True, False, False, True, False, False]
})
